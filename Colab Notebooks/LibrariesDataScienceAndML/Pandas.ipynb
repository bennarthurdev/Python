# %% [markdown]
# Series é um objeto do tipo array unidimensional contendo uma sequência de valores e um array de rótulos denominado índice. Series é também

# %%
from pandas import  Series, DataFrame 
import pandas as pd # dados tabulares e heterogêneos
import numpy as np #use numpy structures is, in general, more efficient of traditional python lists | dados numéricos homogêneos

# %%
def getKeys(series_object):
  keys = list()
  for x , y in series_object.iteritems():
    keys.append(x)
  return keys

# %%
names_list = ['Benn' , 'Bruna' , 'Renato' , 'Fátima' , 'Benjamin']
names = pd.Series(names_list)
id_list = [ "123021",  "02431023 " ,  "012431234 " ,  "01200123 " , "1204301"]
ids = pd.Series(id_list)

users = pd.DataFrame({
    "name" : names,
    "id" : ids
})
names.values
names.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
users['name'] # returns the correspodent series
# Out:
# 0        Benn
# 1       Bruna
# 2      Renato
# 3      Fátima
# 4    Benjamin
# Name: name, dtype: object

# %%
# %%timeit -n 10
#We can change the index atribute by referencing as a optional argument in our series
users = pd.Series(['Benn' , 'Bruna' , 'Renato' , 'Fátima' , 'Benjamin'] , index = ['Me' , 'Wife' , 'Son' , 'Mother' , 'Brother'])
#And we can create new indexes, automatically appended to Series object
users['Second Son'] = 'Noah'
#Series can be intereted as a dict object
getKeys(users)
# Out:
# 744 µs ± 231 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## Dataframes a partir de um array bidimensional

# %% [markdown]
# ### Base teórica:
#  - "Uma tabela talvez seja o meio mais simples de se resumir um conjunto de observações" (Pegano 2004)
#  - Na estatítica descritiva "quebrar" grandes Amostras de dados em outras menores, facilita a obtenção de mais estatísticas para o problema
#  - O pandas pode representar informações tabulares por meio de objetos do tipo

# %%
import numpy as np
rnd_list = np.random.random((2,2))
type(rnd_list)

df = pd.DataFrame(rnd_list , columns = ['col1' , 'col2'] ,index = ['row1' , 'row2'])
df
# Out:
#           col1      col2
# row1  0.858083  0.050007
# row2  0.740782  0.740949

# %%
df[0:3]
# Out:
#           col1      col2
# row1  0.858083  0.050007
# row2  0.740782  0.740949

# %%
row1 = df.loc['row1']
row1
type(row1)

row1[row1 > 0.5]
# Out:
# col1    0.858083
# Name: row1, dtype: float64

# %%
df.T
# Out:
#           row1      row2
# col1  0.858083  0.740782
# col2  0.050007  0.740949

# %% [markdown]
# ### Resumindo e calculando estatísticas descritivas
# - Métodos que extraem um único valor (ex. soma média)
# - Tratamento embutido para dados ausentes
#
# Exemplo: Imagine o dataframe a seguir como a representação das notas de 3 alunos diferentes em uma turma.

# %%
arr = [
    [9.5 , 9 , 9],
    [7 , 10 , 8] , 
    [ 6, 7 , 8]
    
]
#criar dataframe com o objeto "arr"
df = pd.DataFrame(arr , index=['Benn' , 'José' , 'Tonho'] , columns=["av1" , 'av2' , 'av3'])
df
# Out:
#        av1  av2  av3
# Benn   9.5    9    9
# José   7.0   10    8
# Tonho  6.0    7    8

# %%
#Retorna a soma das colunas
df.sum()
# Out:
# av1    22.5
# av2    26.0
# av3    25.0
# dtype: float64

# %%
#Retorna a soma pelas colunas
#df.sum(axis="columns")
df.sum(axis=1)
# Out:
# Benn     27.5
# José     25.0
# Tonho    21.0
# dtype: float64
